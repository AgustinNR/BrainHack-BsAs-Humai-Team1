# %% [markdown]
# # 1. First Approach to the Dataset

# %% [markdown]
# ## 1.1. Environment Setup and Python Libraries Installation
#
# - **Nibabel:** to load and manipulate NIfTI files.
# - **Nilearn:** to facilitate the processing and visualization of neuroimaging data.
# - **Matplotlib and Seaborn:** for data visualization.
# - **Numpy and Pandas:** for data manipulation and analysis.

# %%
# !pip install nibabel nilearn numpy pandas matplotlib seaborn
# Out:
# Requirement already satisfied: nibabel in /home/agustinnr/miniconda3/lib/python3.12/site-packages (5.2.1)
# Requirement already satisfied: nilearn in /home/agustinnr/miniconda3/lib/python3.12/site-packages (0.10.4)
# Requirement already satisfied: numpy in /home/agustinnr/miniconda3/lib/python3.12/site-packages (1.26.4)
# Requirement already satisfied: pandas in /home/agustinnr/miniconda3/lib/python3.12/site-packages (2.2.1)
# Requirement already satisfied: matplotlib in /home/agustinnr/miniconda3/lib/python3.12/site-packages (3.8.4)
# Requirement already satisfied: seaborn in /home/agustinnr/miniconda3/lib/python3.12/site-packages (0.12.2)
# Requirement already satisfied: packaging>=17 in /home/agustinnr/miniconda3/lib/python3.12/site-packages (from nibabel) (23.2)
# Requirement already satisfied: joblib>=1.0.0 in /home/agustinnr/miniconda3/lib/python3.12/site-packages (from nilearn) (1.4.0)
# Requirement already satisfied: lxml in /home/agustinnr/miniconda3/lib/python3.12/site-packages (from nilearn) (5.2.1)
# Requirement already satisfied: requests>=2.25.0 in /home/agustinnr/miniconda3/lib/python3.12/site-packages (from nilearn) (2.31.0)
# Requirement already satisfied: scikit-learn>=1.0.0 in /home/agustinnr/miniconda3/lib/python3.12/site-packages (from nilearn) (1.4.2)
# Requirement already satisfied: scipy>=1.8.0 in /home/agustinnr/miniconda3/lib/python3.12/site-packages (from nilearn) (1.13.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/agustinnr/miniconda3/lib/python3.12/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /home/agustinnr/miniconda3/lib/python3.12/site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /home/agustinnr/miniconda3/lib/python3.12/site-packages (from pandas) (2023.3)
# Requirement already satisfied: contourpy>=1.0.1 in /home/agustinnr/miniconda3/lib/python3.12/site-packages (from matplotlib) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /home/agustinnr/miniconda3/lib/python3.12/site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /home/agustinnr/miniconda3/lib/python3.12/site-packages (from matplotlib) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/agustinnr/miniconda3/lib/python3.12/site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: pillow>=8 in /home/agustinnr/miniconda3/lib/python3.12/site-packages (from matplotlib) (10.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /home/agustinnr/miniconda3/lib/python3.12/site-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: six>=1.5 in /home/agustinnr/miniconda3/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/agustinnr/miniconda3/lib/python3.12/site-packages (from requests>=2.25.0->nilearn) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /home/agustinnr/miniconda3/lib/python3.12/site-packages (from requests>=2.25.0->nilearn) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/agustinnr/miniconda3/lib/python3.12/site-packages (from requests>=2.25.0->nilearn) (2.1.0)
# Requirement already satisfied: certifi>=2017.4.17 in /home/agustinnr/miniconda3/lib/python3.12/site-packages (from requests>=2.25.0->nilearn) (2024.2.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /home/agustinnr/miniconda3/lib/python3.12/site-packages (from scikit-learn>=1.0.0->nilearn) (2.2.0)

# %% [markdown]
# ## 1.2. Data Loading
#
# We load the downloaded ".nii.gz" files using nibabel, a library specialized for handling neuroimaging data.

# %%
import nibabel as nib
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os

"""
Las siguientes líneas de código deben modificarse para correr desde un contenedor Docker
"""

# Ruta de la carpeta actual (donde está el notebook)
current_folder = os.getcwd()

parent_folder = os.path.dirname(current_folder)

# Ruta relativa al archivo .nii.gz
relative_path = r'abide/Outputs/cpac/filt_noglobal/reho/Caltech_0051456_reho.nii.gz'

# Construir la ruta completa usando os.path.join
file_path = os.path.join(parent_folder, relative_path)

# Verificar la ruta
print(file_path)

# Load the NIfTI file
img = nib.load(file_path)
data = img.get_fdata()

print(f"Data shape: {data.shape}")
# Out:
# /home/agustinnr/data/abide/Outputs/cpac/filt_noglobal/reho/Caltech_0051456_reho.nii.gz
# Data shape: (61, 73, 61)

# %% [markdown]
# ## 1.3. Visualize the Data
# We  can visualize slices of the brain to get an initial understanding of the data.

# %%
# Visualize a middle slice of the data
slice_index = data.shape[2] // 2
plt.imshow(data[:, :, slice_index], cmap='gray')
plt.title(f'Slice {slice_index}')
plt.show()

# %% [markdown]
# ## 1.4. Check Data Quality
# Examine basic statistics and check for any obvious issues such as NaNs or extreme values.

# %%
print(f"Data type: {data.dtype}")
print(f"Min value: {np.min(data)}")
print(f"Max value: {np.max(data)}")
print(f"Mean value: {np.mean(data)}")
print(f"Standard deviation: {np.std(data)}")

# Check for NaNs
print(f"Any NaNs in data: {np.isnan(data).any()}")
# Out:
# Data type: float64
# Min value: 0.0
# Max value: 0.3129104673862457
# Mean value: 0.018954227073232778
# Standard deviation: 0.04369735477720224
# Any NaNs in data: False

# %% [markdown]
# ## 1.5. Prepare Data for Machine Learning
#
# In this step we extract features from the brain imaging data. Given that we used ReHo (Regional Homogeneity), we could summarize this measure across different brain regions. We use nilearn to extract region-specific features.

# %%
from nilearn import input_data
from nilearn import datasets

# Load the atlas
atlas = datasets.fetch_atlas_aal()
atlas_filename = atlas.maps

# Create a masker object
masker = input_data.NiftiLabelsMasker(labels_img=atlas_filename, normalization=True)

# Extract the regional homogeneity signals
time_series = masker.fit_transform(file_path)

print(f"Extracted time series shape: {time_series.shape}")
# Out:
# Extracted time series shape: (1, 116)

# %% [markdown]
# ## 1.6. Data Visualization and Statistics

# %% [markdown]
# Once you have the time series data, you can perform further statistical analysis and visualize the extracted features.

# %%
df = pd.DataFrame(time_series, columns=[f"Region_{i}" for i in range(time_series.shape[1])])

df_clean = df

# Summary statistics
print(df_clean.describe())

# Correlation heatmap
plt.figure(figsize=(12, 10))
sns.heatmap(df_clean.corr(), annot=False, cmap='coolwarm', vmin=-1, vmax=1)
plt.title("Correlation between brain regions")
plt.show()
# Out:
#        Region_0  Region_1  Region_2  Region_3  Region_4  Region_5  Region_6  \
# count  1.000000  1.000000  1.000000  1.000000  1.000000   1.00000  1.000000
# mean   0.078748  0.082554  0.091318  0.098637  0.017474   0.04287  0.111249
# std         NaN       NaN       NaN       NaN       NaN       NaN       NaN
# min    0.078748  0.082554  0.091318  0.098637  0.017474   0.04287  0.111249
# 25%    0.078748  0.082554  0.091318  0.098637  0.017474   0.04287  0.111249
# 50%    0.078748  0.082554  0.091318  0.098637  0.017474   0.04287  0.111249
# 75%    0.078748  0.082554  0.091318  0.098637  0.017474   0.04287  0.111249
# max    0.078748  0.082554  0.091318  0.098637  0.017474   0.04287  0.111249
#
#        Region_7  Region_8  Region_9  ...  Region_106  Region_107  Region_108  \
# count  1.000000   1.00000  1.000000  ...     1.00000    1.000000    1.000000
# mean   0.122571   0.05098  0.051863  ...     0.06155    0.002493    0.090025
# std         NaN       NaN       NaN  ...         NaN         NaN         NaN
# min    0.122571   0.05098  0.051863  ...     0.06155    0.002493    0.090025
# 25%    0.122571   0.05098  0.051863  ...     0.06155    0.002493    0.090025
# 50%    0.122571   0.05098  0.051863  ...     0.06155    0.002493    0.090025
# 75%    0.122571   0.05098  0.051863  ...     0.06155    0.002493    0.090025
# max    0.122571   0.05098  0.051863  ...     0.06155    0.002493    0.090025
#
#        Region_109  Region_110  Region_111  Region_112  Region_113  Region_114  \
# count    1.000000    1.000000    1.000000    1.000000    1.000000    1.000000
# mean     0.117448    0.190953    0.055819    0.011085    0.026962    0.095908
# std           NaN         NaN         NaN         NaN         NaN         NaN
# min      0.117448    0.190953    0.055819    0.011085    0.026962    0.095908
# 25%      0.117448    0.190953    0.055819    0.011085    0.026962    0.095908
# 50%      0.117448    0.190953    0.055819    0.011085    0.026962    0.095908
# 75%      0.117448    0.190953    0.055819    0.011085    0.026962    0.095908
# max      0.117448    0.190953    0.055819    0.011085    0.026962    0.095908
#
#        Region_115
# count    1.000000
# mean     0.163749
# std           NaN
# min      0.163749
# 25%      0.163749
# 50%      0.163749
# 75%      0.163749
# max      0.163749
#
# [8 rows x 116 columns]
