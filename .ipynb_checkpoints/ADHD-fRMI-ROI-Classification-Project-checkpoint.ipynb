# %% [markdown]
# # 1. First Approach to the Dataset

# %% [markdown]
# ## 1.1. Environment Setup and Python Libraries Installation
#
# - **Nilearn:** to facilitate the processing and visualization of neuroimaging data.
# - **Matplotlib and Seaborn:** for data visualization.
# - **Numpy and Pandas:** for data manipulation and analysis.

# %%
# !pip install nilearn numpy pandas matplotlib seaborn
# Out:
# Requirement already satisfied: nilearn in /home/agustinnr/miniconda3/lib/python3.12/site-packages (0.10.4)
# Requirement already satisfied: numpy in /home/agustinnr/miniconda3/lib/python3.12/site-packages (1.26.4)
# Requirement already satisfied: pandas in /home/agustinnr/miniconda3/lib/python3.12/site-packages (2.2.1)
# Requirement already satisfied: matplotlib in /home/agustinnr/miniconda3/lib/python3.12/site-packages (3.8.4)
# Requirement already satisfied: seaborn in /home/agustinnr/miniconda3/lib/python3.12/site-packages (0.12.2)
# Requirement already satisfied: joblib>=1.0.0 in /home/agustinnr/miniconda3/lib/python3.12/site-packages (from nilearn) (1.4.0)
# Requirement already satisfied: lxml in /home/agustinnr/miniconda3/lib/python3.12/site-packages (from nilearn) (5.2.1)
# Requirement already satisfied: nibabel>=4.0.0 in /home/agustinnr/miniconda3/lib/python3.12/site-packages (from nilearn) (5.2.1)
# Requirement already satisfied: packaging in /home/agustinnr/miniconda3/lib/python3.12/site-packages (from nilearn) (23.2)
# Requirement already satisfied: requests>=2.25.0 in /home/agustinnr/miniconda3/lib/python3.12/site-packages (from nilearn) (2.31.0)
# Requirement already satisfied: scikit-learn>=1.0.0 in /home/agustinnr/miniconda3/lib/python3.12/site-packages (from nilearn) (1.4.2)
# Requirement already satisfied: scipy>=1.8.0 in /home/agustinnr/miniconda3/lib/python3.12/site-packages (from nilearn) (1.13.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/agustinnr/miniconda3/lib/python3.12/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /home/agustinnr/miniconda3/lib/python3.12/site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /home/agustinnr/miniconda3/lib/python3.12/site-packages (from pandas) (2023.3)
# Requirement already satisfied: contourpy>=1.0.1 in /home/agustinnr/miniconda3/lib/python3.12/site-packages (from matplotlib) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /home/agustinnr/miniconda3/lib/python3.12/site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /home/agustinnr/miniconda3/lib/python3.12/site-packages (from matplotlib) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/agustinnr/miniconda3/lib/python3.12/site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: pillow>=8 in /home/agustinnr/miniconda3/lib/python3.12/site-packages (from matplotlib) (10.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /home/agustinnr/miniconda3/lib/python3.12/site-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: six>=1.5 in /home/agustinnr/miniconda3/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/agustinnr/miniconda3/lib/python3.12/site-packages (from requests>=2.25.0->nilearn) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /home/agustinnr/miniconda3/lib/python3.12/site-packages (from requests>=2.25.0->nilearn) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/agustinnr/miniconda3/lib/python3.12/site-packages (from requests>=2.25.0->nilearn) (2.1.0)
# Requirement already satisfied: certifi>=2017.4.17 in /home/agustinnr/miniconda3/lib/python3.12/site-packages (from requests>=2.25.0->nilearn) (2024.2.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /home/agustinnr/miniconda3/lib/python3.12/site-packages (from scikit-learn>=1.0.0->nilearn) (2.2.0)

# %% [markdown]
# ## 1.2. Data Loading
#
# We established the file path using the os library and loaded the downloaded ".1D" files using numpy.

# %%
import nilearn
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os
import json

"""
Las siguientes líneas de código deben modificarse para correr desde un contenedor Docker
"""

# Ruta de la carpeta actual (donde está el notebook)
current_folder = os.getcwd()

parent_folder = os.path.dirname(current_folder)

# Ruta relativa al archivo .nii.gz
relative_path = r'Dataset_ROIs_AAL_CCS_filt_noglobal/Caltech_0051456_rois_aal.1D'

# Construir la ruta completa usando os.path.join
file_path = os.path.join(parent_folder, relative_path)

time_series_data = np.loadtxt(file_path)

# Display the shape of the loaded data
print("Shape of the loaded data array:", time_series_data.shape)

print(time_series_data)
# Out:
# Shape of the loaded data array: (145, 116)
# [[7039.58496094 9013.60742188 5527.58203125 ... 3546.25
#   5282.50537109 6146.91308594]
#  [7039.40673828 9013.36425781 5527.59570312 ... 3548.40087891
#   5283.90478516 6146.7265625 ]
#  [7036.66455078 9009.55957031 5528.86572266 ... 3544.45043945
#   5278.00195312 6150.76220703]
#  ...
#  [7031.11132812 9004.52148438 5521.82324219 ... 3634.96923828
#   5378.97851562 6153.30126953]
#  [7040.75390625 9015.99902344 5522.64550781 ... 3599.42260742
#   5329.28222656 6142.60205078]
#  [7049.0234375  9026.19921875 5526.52880859 ... 3525.44091797
#   5263.59960938 6146.12597656]]

# %% [markdown]
# ## 1.3. Visualize the Data
# We can visualize the rs-fMRI signal of on subject to get an initial understanding of the data.

# %%
# Plotting the time series data
plt.figure(figsize=(9, 5))
plt.plot(time_series_data)
plt.xlabel('Time Points')
plt.ylabel('Intensity')
plt.title('Sample Time Series Data')
plt.grid(True)
plt.show()

# %% [markdown]
# ## 1.3.1 A look at the AAL Atlas used in this brain parcellation:

# %%
from nilearn import datasets
from nilearn import plotting
# Load the atlas
atlas = datasets.fetch_atlas_aal()
atlas_filename = atlas.maps
atlas_labels = atlas.labels
atlas_indices = atlas.indices
atlas_description = atlas.description  
print(atlas_filename)
plotting.plot_roi(atlas_filename, draw_cross=False, annotate=False, alpha=0.75)

parcellations = datasets.fetch_atlas_basc_multiscale_2015(version='sym')
aal_atlas_filename = parcellations.scale122
#possible scales:007,012,020,064,122,197,325,444
print(aal_atlas_filename)

plotting.plot_roi(aal_atlas_filename, draw_cross=False, annotate=False, alpha=0.75)
print(len(atlas_labels))
print("Atlas labels:", atlas_labels)
# Out:
# /home/agustinnr/nilearn_data/aal_SPM12/aal/atlas/AAL.nii
# /home/agustinnr/nilearn_data/basc_multiscale_2015/template_cambridge_basc_multiscale_nii_sym/template_cambridge_basc_multiscale_sym_scale122.nii.gz
# 116
# Atlas labels: ['Precentral_L', 'Precentral_R', 'Frontal_Sup_L', 'Frontal_Sup_R', 'Frontal_Sup_Orb_L', 'Frontal_Sup_Orb_R', 'Frontal_Mid_L', 'Frontal_Mid_R', 'Frontal_Mid_Orb_L', 'Frontal_Mid_Orb_R', 'Frontal_Inf_Oper_L', 'Frontal_Inf_Oper_R', 'Frontal_Inf_Tri_L', 'Frontal_Inf_Tri_R', 'Frontal_Inf_Orb_L', 'Frontal_Inf_Orb_R', 'Rolandic_Oper_L', 'Rolandic_Oper_R', 'Supp_Motor_Area_L', 'Supp_Motor_Area_R', 'Olfactory_L', 'Olfactory_R', 'Frontal_Sup_Medial_L', 'Frontal_Sup_Medial_R', 'Frontal_Med_Orb_L', 'Frontal_Med_Orb_R', 'Rectus_L', 'Rectus_R', 'Insula_L', 'Insula_R', 'Cingulum_Ant_L', 'Cingulum_Ant_R', 'Cingulum_Mid_L', 'Cingulum_Mid_R', 'Cingulum_Post_L', 'Cingulum_Post_R', 'Hippocampus_L', 'Hippocampus_R', 'ParaHippocampal_L', 'ParaHippocampal_R', 'Amygdala_L', 'Amygdala_R', 'Calcarine_L', 'Calcarine_R', 'Cuneus_L', 'Cuneus_R', 'Lingual_L', 'Lingual_R', 'Occipital_Sup_L', 'Occipital_Sup_R', 'Occipital_Mid_L', 'Occipital_Mid_R', 'Occipital_Inf_L', 'Occipital_Inf_R', 'Fusiform_L', 'Fusiform_R', 'Postcentral_L', 'Postcentral_R', 'Parietal_Sup_L', 'Parietal_Sup_R', 'Parietal_Inf_L', 'Parietal_Inf_R', 'SupraMarginal_L', 'SupraMarginal_R', 'Angular_L', 'Angular_R', 'Precuneus_L', 'Precuneus_R', 'Paracentral_Lobule_L', 'Paracentral_Lobule_R', 'Caudate_L', 'Caudate_R', 'Putamen_L', 'Putamen_R', 'Pallidum_L', 'Pallidum_R', 'Thalamus_L', 'Thalamus_R', 'Heschl_L', 'Heschl_R', 'Temporal_Sup_L', 'Temporal_Sup_R', 'Temporal_Pole_Sup_L', 'Temporal_Pole_Sup_R', 'Temporal_Mid_L', 'Temporal_Mid_R', 'Temporal_Pole_Mid_L', 'Temporal_Pole_Mid_R', 'Temporal_Inf_L', 'Temporal_Inf_R', 'Cerebelum_Crus1_L', 'Cerebelum_Crus1_R', 'Cerebelum_Crus2_L', 'Cerebelum_Crus2_R', 'Cerebelum_3_L', 'Cerebelum_3_R', 'Cerebelum_4_5_L', 'Cerebelum_4_5_R', 'Cerebelum_6_L', 'Cerebelum_6_R', 'Cerebelum_7b_L', 'Cerebelum_7b_R', 'Cerebelum_8_L', 'Cerebelum_8_R', 'Cerebelum_9_L', 'Cerebelum_9_R', 'Cerebelum_10_L', 'Cerebelum_10_R', 'Vermis_1_2', 'Vermis_3', 'Vermis_4_5', 'Vermis_6', 'Vermis_7', 'Vermis_8', 'Vermis_9', 'Vermis_10']

# %% [markdown]
# ### Otras pruebas

# %%
#data = datasets.fetch_development_fmri()

# %% [markdown]
# # 1.4. Individual Correlation Matrix

# %%
# Calculate the correlation matrix
correlation_matrix = np.corrcoef(time_series_data.T)  # Transpose so that rows represent different ROIs

# Plot the correlation matrix using a heatmap
plt.figure(figsize=(7, 5))
sns.heatmap(correlation_matrix, annot=False, cmap='coolwarm', vmin=-1, vmax=1)
plt.title('Correlation Matrix for One Subject')
plt.xlabel('ROIs')
plt.ylabel('ROIs')
plt.show()

# %% [markdown]
# # 1.5. Cleaning the Individual Correlation Matrix

# %%
#Plotting just the lower triangule of the correlation matrix:
lower_triangule = np.tril(correlation_matrix, k=-1)

plt.figure(figsize=(7, 5))
sns.heatmap(lower_triangule, annot=False, cmap='coolwarm', vmin=-1, vmax=1)
plt.title('Clean Correlation Matrix for One Subject')
plt.xlabel('ROIs')
plt.ylabel('ROIs')
plt.show()

# %% [markdown]
# # 1.6. Vectorizing the Cleaned Individual Correlation Matrix
#
# #### This method ordered rows-wise from the lower triangular matrix. Specifically, the order follows:
#
# - All elements from the first row below the diagonal.
# - All elements from the second row below the diagonal.
# - And so on, up to the last row.

# %%
lower_triangle_indices = np.tril_indices(correlation_matrix.shape[0], k=-1)

vectorized_lower_triangle = lower_triangule[lower_triangle_indices]

print("Vector with the elements of the lower half of the one subject correlation matrix (without the diagonal):\n", vectorized_lower_triangle)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 lower_triangle_indices = np.tril_indices(correlation_matrix.shape[0], k=-1)
#       3 vectorized_lower_triangle = lower_triangule[lower_triangle_indices]
#       5 print("Vector with the elements of the lower half of the one subject correlation matrix (without the diagonal):\n", vectorized_lower_triangle)
#
# NameError: name 'np' is not defined

# %% [markdown]
# # 1.7. Checking the Quality of the Vector

# %%
vector = vectorized_lower_triangle
print(f"Data type: {vector.dtype}")
print(f"Min value: {np.min(vector)}")
print(f"Max value: {np.max(vector)}")
print(f"Mean value: {np.mean(vector)}")
print(f"Standard deviation: {np.std(vector)}")
print(f"Lenght: {len(vector)}")
# Check for NaNs
print(f"Any NaNs in data: {np.isnan(vector).any()}")
print("---"*8)
print("First 7 values of the vector:")
print(vector[:6])
# Out:
# Data type: float64
# Min value: -0.7159769020698279
# Max value: 0.9488359071435615
# Mean value: 0.32107573075109536
# Standard deviation: 0.28906254610274096
# Lenght: 6670
# Any NaNs in data: False
# ------------------------
# First 7 values of the vector:
# [0.87438559 0.70989999 0.63884253 0.64194977 0.67877505 0.82084473]

# %% [markdown]
# # 2. Loop to create the initial DataFrame

# %%
# Obtener la ruta del directorio actual y el directorio padre
current_folder = os.getcwd()
parent_folder = os.path.dirname(current_folder)

# Definir el archivo CSV y su ruta
csv_file = 'Phenotypic_simplified.csv'
csv_path = os.path.join(current_folder, csv_file)

# Cargar el archivo CSV en un DataFrame
df = pd.read_csv(csv_path, sep=";")

# Nombres de las ROIs del atlas AAL
roi_names = atlas.labels
# Inicializar una lista para almacenar los vectores del triángulo inferior de las matrices de correlación
vectorized_data = []

# Inicializar contadores
count_valid = 0
count_error = 0

# Recorrer cada fila del DataFrame y calcular la matriz de correlación, eliminando las filas donde no existe el archivo
for index, row in df.iterrows():
    file_id_value = row['FILE_ID']
    relative_path = f'Dataset_ROIs_AAL_CCS_filt_noglobal/{file_id_value}_rois_aal.1D'
    file_path = os.path.join(parent_folder, relative_path)
    
    # Verificar si el archivo existe
    if os.path.exists(file_path):
        try:
            # Cargar los datos de la serie temporal
            time_series_data = np.loadtxt(file_path)
            
            # Verificar que no haya series con desviación estándar cero
            if np.any(np.std(time_series_data, axis=0) == 0):
                raise ValueError("Desviación estándar cero encontrada en alguna serie temporal")
            
            # Calcular el vector del triángulo inferior de la matriz de correlación
            correlation_matrix = np.corrcoef(time_series_data.T)
            lower_triangle_indices = np.tril_indices(correlation_matrix.shape[0], k=-1)
            vectorized_lower_triangle = correlation_matrix[lower_triangle_indices]
            vectorized_data.append(vectorized_lower_triangle)
            count_valid += 1
        except Exception as e:
            print(f"Error procesando el archivo: {file_path}\n{e}")
            count_error += 1
    else:
        # Eliminar la fila si el archivo no existe
        df.drop(index, inplace=True)

# Imprimir la longitud del vectorizado para el diagnóstico
if vectorized_data:
    print(f"Longitud de vectorized_lower_triangle: {len(vectorized_lower_triangle)}")

# Ajustar el número de nombres de ROI si es necesario
num_columns = len(vectorized_lower_triangle)
if len(roi_names) < num_columns:
    roi_names = roi_names + [f"ROI_{i}" for i in range(len(roi_names), num_columns)]

# Crear un DataFrame con los nombres de las ROIs en la primera fila y los datos vectorizados en las demás filas
if vectorized_data:  # Verificar que haya datos para evitar errores
    output_df = pd.DataFrame(vectorized_data, columns=roi_names[:num_columns])
else:
    output_df = pd.DataFrame(columns=roi_names)

# Guardar el DataFrame limpio en un nuevo archivo CSV
clean_csv_path = os.path.join(parent_folder, 'Phenotypic_simplified_clean.csv')
df.to_csv(clean_csv_path, index=False)

# Guardar el DataFrame con los vectores de correlación en un nuevo archivo CSV
output_file_path = os.path.join(parent_folder, 'output_file.csv')
output_df.to_csv(output_file_path, index=False)

# Imprimir los primeros 10 valores de vectorized_data
print("Primeros 10 valores de vectorized_data:")
for vector in vectorized_data[:10]:
    print(vector)

print(f"Archivos procesados correctamente: {count_valid}")
print(f"Archivos con errores: {count_error}")
print("CSV limpio y actualizado guardado correctamente.")

"""
# Crear un DataFrame con los nombres de las ROIs en la primera fila y los datos vectorizados en las demás filas
#output_df = pd.DataFrame(vectorized_data, columns=roi_names[:len(vectorized_data)])
output_df = pd.DataFrame(
# Guardar el DataFrame en un nuevo archivo CSV
output_file_path = os.path.join(parent_folder, 'Phenotypic_simplified_clean.csv')
output_df.to_csv(output_file_path, index=False)

print("CSV actualizado y guardado correctamente.")
"""
# Out:
# Error procesando el archivo: /home/agustinnr/data/Dataset_ROIs_AAL_CCS_filt_noglobal/Pitt_0050004_rois_aal.1D
# Desviación estándar cero encontrada en alguna serie temporal
# Error procesando el archivo: /home/agustinnr/data/Dataset_ROIs_AAL_CCS_filt_noglobal/Pitt_0050007_rois_aal.1D
# Desviación estándar cero encontrada en alguna serie temporal
# Error procesando el archivo: /home/agustinnr/data/Dataset_ROIs_AAL_CCS_filt_noglobal/Pitt_0050011_rois_aal.1D
# Desviación estándar cero encontrada en alguna serie temporal
# Error procesando el archivo: /home/agustinnr/data/Dataset_ROIs_AAL_CCS_filt_noglobal/Pitt_0050016_rois_aal.1D
# Desviación estándar cero encontrada en alguna serie temporal
# Error procesando el archivo: /home/agustinnr/data/Dataset_ROIs_AAL_CCS_filt_noglobal/Pitt_0050024_rois_aal.1D
# Desviación estándar cero encontrada en alguna serie temporal
# Error procesando el archivo: /home/agustinnr/data/Dataset_ROIs_AAL_CCS_filt_noglobal/Pitt_0050032_rois_aal.1D
# Desviación estándar cero encontrada en alguna serie temporal
# Error procesando el archivo: /home/agustinnr/data/Dataset_ROIs_AAL_CCS_filt_noglobal/Pitt_0050035_rois_aal.1D
# Desviación estándar cero encontrada en alguna serie temporal
# Error procesando el archivo: /home/agustinnr/data/Dataset_ROIs_AAL_CCS_filt_noglobal/Pitt_0050037_rois_aal.1D
# Desviación estándar cero encontrada en alguna serie temporal
# Error procesando el archivo: /home/agustinnr/data/Dataset_ROIs_AAL_CCS_filt_noglobal/Pitt_0050041_rois_aal.1D
# Desviación estándar cero encontrada en alguna serie temporal
# Error procesando el archivo: /home/agustinnr/data/Dataset_ROIs_AAL_CCS_filt_noglobal/Pitt_0050044_rois_aal.1D
# Desviación estándar cero encontrada en alguna serie temporal
# Error procesando el archivo: /home/agustinnr/data/Dataset_ROIs_AAL_CCS_filt_noglobal/Pitt_0050045_rois_aal.1D
# Desviación estándar cero encontrada en alguna serie temporal
# Error procesando el archivo: /home/agustinnr/data/Dataset_ROIs_AAL_CCS_filt_noglobal/Pitt_0050050_rois_aal.1D
# Desviación estándar cero encontrada en alguna serie temporal
# Error procesando el archivo: /home/agustinnr/data/Dataset_ROIs_AAL_CCS_filt_noglobal/Pitt_0050052_rois_aal.1D
# Desviación estándar cero encontrada en alguna serie temporal
# Error procesando el archivo: /home/agustinnr/data/Dataset_ROIs_AAL_CCS_filt_noglobal/Pitt_0050060_rois_aal.1D
# Desviación estándar cero encontrada en alguna serie temporal
# Error procesando el archivo: /home/agustinnr/data/Dataset_ROIs_AAL_CCS_filt_noglobal/SDSU_0050182_rois_aal.1D
# Desviación estándar cero encontrada en alguna serie temporal
# Error procesando el archivo: /home/agustinnr/data/Dataset_ROIs_AAL_CCS_filt_noglobal/SDSU_0050208_rois_aal.1D
# Desviación estándar cero encontrada en alguna serie temporal
# Error procesando el archivo: /home/agustinnr/data/Dataset_ROIs_AAL_CCS_filt_noglobal/UM_1_0050280_rois_aal.1D
# Desviación estándar cero encontrada en alguna serie temporal
# Error procesando el archivo: /home/agustinnr/data/Dataset_ROIs_AAL_CCS_filt_noglobal/UM_1_0050283_rois_aal.1D
# Desviación estándar cero encontrada en alguna serie temporal
# Error procesando el archivo: /home/agustinnr/data/Dataset_ROIs_AAL_CCS_filt_noglobal/UM_1_0050287_rois_aal.1D
# Desviación estándar cero encontrada en alguna serie temporal
# Error procesando el archivo: /home/agustinnr/data/Dataset_ROIs_AAL_CCS_filt_noglobal/UM_1_0050347_rois_aal.1D
# Desviación estándar cero encontrada en alguna serie temporal
# Error procesando el archivo: /home/agustinnr/data/Dataset_ROIs_AAL_CCS_filt_noglobal/Yale_0050557_rois_aal.1D
# Desviación estándar cero encontrada en alguna serie temporal
# Error procesando el archivo: /home/agustinnr/data/Dataset_ROIs_AAL_CCS_filt_noglobal/CMU_b_0050651_rois_aal.1D
# Desviación estándar cero encontrada en alguna serie temporal
# Error procesando el archivo: /home/agustinnr/data/Dataset_ROIs_AAL_CCS_filt_noglobal/CMU_a_0050653_rois_aal.1D
# Desviación estándar cero encontrada en alguna serie temporal
# Error procesando el archivo: /home/agustinnr/data/Dataset_ROIs_AAL_CCS_filt_noglobal/CMU_b_0050657_rois_aal.1D
# Desviación estándar cero encontrada en alguna serie temporal
# Error procesando el archivo: /home/agustinnr/data/Dataset_ROIs_AAL_CCS_filt_noglobal/CMU_b_0050669_rois_aal.1D
# Desviación estándar cero encontrada en alguna serie temporal
# Error procesando el archivo: /home/agustinnr/data/Dataset_ROIs_AAL_CCS_filt_noglobal/Leuven_2_0050727_rois_aal.1D
# Desviación estándar cero encontrada en alguna serie temporal
# Error procesando el archivo: /home/agustinnr/data/Dataset_ROIs_AAL_CCS_filt_noglobal/NYU_0051123_rois_aal.1D
# Desviación estándar cero encontrada en alguna serie temporal
# Error procesando el archivo: /home/agustinnr/data/Dataset_ROIs_AAL_CCS_filt_noglobal/UCLA_1_0051208_rois_aal.1D
# Desviación estándar cero encontrada en alguna serie temporal
# Error procesando el archivo: /home/agustinnr/data/Dataset_ROIs_AAL_CCS_filt_noglobal/MaxMun_c_0051332_rois_aal.1D
# Desviación estándar cero encontrada en alguna serie temporal
# Error procesando el archivo: /home/agustinnr/data/Dataset_ROIs_AAL_CCS_filt_noglobal/MaxMun_c_0051336_rois_aal.1D
# Desviación estándar cero encontrada en alguna serie temporal
# Error procesando el archivo: /home/agustinnr/data/Dataset_ROIs_AAL_CCS_filt_noglobal/MaxMun_a_0051364_rois_aal.1D
# Desviación estándar cero encontrada en alguna serie temporal
# Error procesando el archivo: /home/agustinnr/data/Dataset_ROIs_AAL_CCS_filt_noglobal/Caltech_0051457_rois_aal.1D
# Desviación estándar cero encontrada en alguna serie temporal
# Error procesando el archivo: /home/agustinnr/data/Dataset_ROIs_AAL_CCS_filt_noglobal/Caltech_0051458_rois_aal.1D
# Desviación estándar cero encontrada en alguna serie temporal
# Error procesando el archivo: /home/agustinnr/data/Dataset_ROIs_AAL_CCS_filt_noglobal/Caltech_0051459_rois_aal.1D
# Desviación estándar cero encontrada en alguna serie temporal
# Error procesando el archivo: /home/agustinnr/data/Dataset_ROIs_AAL_CCS_filt_noglobal/Caltech_0051460_rois_aal.1D
# Desviación estándar cero encontrada en alguna serie temporal
# Error procesando el archivo: /home/agustinnr/data/Dataset_ROIs_AAL_CCS_filt_noglobal/Caltech_0051464_rois_aal.1D
# Desviación estándar cero encontrada en alguna serie temporal
# Error procesando el archivo: /home/agustinnr/data/Dataset_ROIs_AAL_CCS_filt_noglobal/Caltech_0051467_rois_aal.1D
# Desviación estándar cero encontrada en alguna serie temporal
# Error procesando el archivo: /home/agustinnr/data/Dataset_ROIs_AAL_CCS_filt_noglobal/Caltech_0051468_rois_aal.1D
# Desviación estándar cero encontrada en alguna serie temporal
# Error procesando el archivo: /home/agustinnr/data/Dataset_ROIs_AAL_CCS_filt_noglobal/Caltech_0051469_rois_aal.1D
# Desviación estándar cero encontrada en alguna serie temporal
# Error procesando el archivo: /home/agustinnr/data/Dataset_ROIs_AAL_CCS_filt_noglobal/Caltech_0051471_rois_aal.1D
# Desviación estándar cero encontrada en alguna serie temporal
# Error procesando el archivo: /home/agustinnr/data/Dataset_ROIs_AAL_CCS_filt_noglobal/Caltech_0051473_rois_aal.1D
# Desviación estándar cero encontrada en alguna serie temporal
# Error procesando el archivo: /home/agustinnr/data/Dataset_ROIs_AAL_CCS_filt_noglobal/Caltech_0051478_rois_aal.1D
# Desviación estándar cero encontrada en alguna serie temporal
# Error procesando el archivo: /home/agustinnr/data/Dataset_ROIs_AAL_CCS_filt_noglobal/Caltech_0051483_rois_aal.1D
# Desviación estándar cero encontrada en alguna serie temporal
# Error procesando el archivo: /home/agustinnr/data/Dataset_ROIs_AAL_CCS_filt_noglobal/Caltech_0051485_rois_aal.1D
# Desviación estándar cero encontrada en alguna serie temporal
# Error procesando el archivo: /home/agustinnr/data/Dataset_ROIs_AAL_CCS_filt_noglobal/Caltech_0051489_rois_aal.1D
# Desviación estándar cero encontrada en alguna serie temporal
# Error procesando el archivo: /home/agustinnr/data/Dataset_ROIs_AAL_CCS_filt_noglobal/Caltech_0051490_rois_aal.1D
# Desviación estándar cero encontrada en alguna serie temporal
# Error procesando el archivo: /home/agustinnr/data/Dataset_ROIs_AAL_CCS_filt_noglobal/SBL_0051558_rois_aal.1D
# Desviación estándar cero encontrada en alguna serie temporal
# Error procesando el archivo: /home/agustinnr/data/Dataset_ROIs_AAL_CCS_filt_noglobal/SBL_0051560_rois_aal.1D
# Desviación estándar cero encontrada en alguna serie temporal
# Error procesando el archivo: /home/agustinnr/data/Dataset_ROIs_AAL_CCS_filt_noglobal/SBL_0051562_rois_aal.1D
# Desviación estándar cero encontrada en alguna serie temporal
# Error procesando el archivo: /home/agustinnr/data/Dataset_ROIs_AAL_CCS_filt_noglobal/SBL_0051564_rois_aal.1D
# Desviación estándar cero encontrada en alguna serie temporal
# Error procesando el archivo: /home/agustinnr/data/Dataset_ROIs_AAL_CCS_filt_noglobal/SBL_0051565_rois_aal.1D
# Desviación estándar cero encontrada en alguna serie temporal
# Error procesando el archivo: /home/agustinnr/data/Dataset_ROIs_AAL_CCS_filt_noglobal/SBL_0051566_rois_aal.1D
# Desviación estándar cero encontrada en alguna serie temporal
# Error procesando el archivo: /home/agustinnr/data/Dataset_ROIs_AAL_CCS_filt_noglobal/SBL_0051567_rois_aal.1D
# Desviación estándar cero encontrada en alguna serie temporal
# Error procesando el archivo: /home/agustinnr/data/Dataset_ROIs_AAL_CCS_filt_noglobal/SBL_0051571_rois_aal.1D
# Desviación estándar cero encontrada en alguna serie temporal
# Error procesando el archivo: /home/agustinnr/data/Dataset_ROIs_AAL_CCS_filt_noglobal/SBL_0051572_rois_aal.1D
# Desviación estándar cero encontrada en alguna serie temporal
# Error procesando el archivo: /home/agustinnr/data/Dataset_ROIs_AAL_CCS_filt_noglobal/SBL_0051573_rois_aal.1D
# Desviación estándar cero encontrada en alguna serie temporal
# Error procesando el archivo: /home/agustinnr/data/Dataset_ROIs_AAL_CCS_filt_noglobal/SBL_0051577_rois_aal.1D
# Desviación estándar cero encontrada en alguna serie temporal
# Error procesando el archivo: /home/agustinnr/data/Dataset_ROIs_AAL_CCS_filt_noglobal/SBL_0051578_rois_aal.1D
# Desviación estándar cero encontrada en alguna serie temporal
# Error procesando el archivo: /home/agustinnr/data/Dataset_ROIs_AAL_CCS_filt_noglobal/SBL_0051579_rois_aal.1D
# Desviación estándar cero encontrada en alguna serie temporal
# Error procesando el archivo: /home/agustinnr/data/Dataset_ROIs_AAL_CCS_filt_noglobal/SBL_0051580_rois_aal.1D
# Desviación estándar cero encontrada en alguna serie temporal
# Error procesando el archivo: /home/agustinnr/data/Dataset_ROIs_AAL_CCS_filt_noglobal/SBL_0051582_rois_aal.1D
# Desviación estándar cero encontrada en alguna serie temporal
# Error procesando el archivo: /home/agustinnr/data/Dataset_ROIs_AAL_CCS_filt_noglobal/SBL_0051583_rois_aal.1D
# Desviación estándar cero encontrada en alguna serie temporal
# Error procesando el archivo: /home/agustinnr/data/Dataset_ROIs_AAL_CCS_filt_noglobal/SBL_0051584_rois_aal.1D
# Desviación estándar cero encontrada en alguna serie temporal
# Error procesando el archivo: /home/agustinnr/data/Dataset_ROIs_AAL_CCS_filt_noglobal/SBL_0051585_rois_aal.1D
# Desviación estándar cero encontrada en alguna serie temporal
# Longitud de vectorized_lower_triangle: 6670
# Primeros 10 valores de vectorized_data:
# [ 0.87081332  0.80506962  0.69317594 ...  0.06752915 -0.24956816
#  -0.14340012]
# [0.89827142 0.53001389 0.45809058 ... 0.36411057 0.2316052  0.17584541]
# [ 0.69472004  0.61775567  0.64061112 ...  0.27544809 -0.03810095
#   0.14642138]
# [0.79580921 0.70491748 0.66200757 ... 0.16770473 0.08287514 0.73142311]
# [ 0.69804583  0.33904316  0.65889112 ... -0.12013095  0.28436789
#   0.44352389]
# [ 0.92135586  0.91656549  0.90383206 ... -0.07657402 -0.32128013
#  -0.2230582 ]
# [ 0.48482541  0.45315294  0.08209287 ...  0.10493342 -0.01678704
#   0.20281378]
# [ 0.4621814   0.2056749   0.17089594 ...  0.41070655 -0.00102263
#   0.05105941]
# [0.79996822 0.84749775 0.69539989 ... 0.16744629 0.1051129  0.16212269]
# [ 0.92036423  0.7641545   0.7107854  ...  0.10870398 -0.03711333
#   0.15840046]
# Archivos procesados correctamente: 820
# Archivos con errores: 64
# CSV limpio y actualizado guardado correctamente.
# '\n# Crear un DataFrame con los nombres de las ROIs en la primera fila y los datos vectorizados en las demás filas\n#output_df = pd.DataFrame(vectorized_data, columns=roi_names[:len(vectorized_data)])\noutput_df = pd.DataFrame(\n# Guardar el DataFrame en un nuevo archivo CSV\noutput_file_path = os.path.join(parent_folder, \'Phenotypic_simplified_clean.csv\')\noutput_df.to_csv(output_file_path, index=False)\n\nprint("CSV actualizado y guardado correctamente.")\n'
